# %% [markdown]
# # Домашняя работа "Обучение сверточной сети на практике". Тян Е.В.
#
# ## Задание
#
# Обучить модель классификации изображение на 2 класса. Исходные данные и валидация решения на kaggle в рамках контеста Cats vs Dogs. Шаблон ipython-ноутбука для решения можно скачать по ссылке. Решения необходимо прислать в виде ipython-ноутбука с указанием значения метрики на Leaderboard. Задание засчитывается при значениях метрики Log Loss меньше 0.3.

# %% [markdown]
# ## Решение

# %%
import os
import random
import glob
import numpy as np
import cv2
import tensorflow as tf

from keras.applications import vgg16
from matplotlib import pyplot as plt
from keras.saving import load_model

# %% [markdown]
# ### Вспомогательные функции

# %%
IMG_SIZE = (224, 224)  # размер входного изображения сети

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        random.shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)]),

# %% [markdown]
# ### Соберем пути файлов c картинками

# %%
train_files = glob.glob('data/train/*.jpg')
test_files = glob.glob('data/test/*.jpg')

# %% [markdown]
# ### Визуализируем входные данные

# %%
# %matplotlib inline

fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ### Загрузим предобученную модель

# %%
# pretrained_model - объект класса keras.models.Model (Functional Model)
pretrained_model = vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
pretrained_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Создадим свою модель

# %%
# фиксируем все веса предобученной сети
for layer in pretrained_model.layers:
    layer.trainable = False

x = pretrained_model.layers[-5].output
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(10,  activation='relu',  kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)
x = tf.keras.layers.Dense(1,  activation='sigmoid',  kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)
model = tf.keras.Model(inputs=pretrained_model.input, outputs=x, name='dogs_vs_cats')

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_17 (Flatten)            │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 10)             │     1,003,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,640,853 (32.96 MB)
#  Trainable params: 1,004,565 (3.83 MB)
#  Non-trainable params: 7,636,288 (29.13 MB)

# %% [markdown]
# ### Компилируем модель и запускаем модель

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
val_samples = 100  # число изображений в валидационной выборке

random.shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('debug/9_2/model_{epoch}.keras', monitor='val_loss', save_best_only=False)
# запускаем процесс обучения
model.fit(train_data,
          callbacks = [model_checkpoint],
          steps_per_epoch=30,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 0.9854 - loss: 0.2724 - val_accuracy: 0.9700 - val_loss: 0.3028
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9823 - loss: 0.2731 - val_accuracy: 0.9800 - val_loss: 0.2622
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9833 - loss: 0.2823 - val_accuracy: 0.9800 - val_loss: 0.3581
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9854 - loss: 0.3894 - val_accuracy: 0.9600 - val_loss: 0.4437
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.9844 - loss: 0.3647 - val_accuracy: 0.9600 - val_loss: 0.3733
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9823 - loss: 0.3469 - val_accuracy: 0.9600 - val_loss: 0.3451
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.9802 - loss: 0.3714 - val_accuracy: 0.9800 - val_loss: 0.3723
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.9833 - loss: 0.3688 - val_accuracy: 0.9600 - val_loss: 0.3599
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - accuracy: 0.9802 - loss: 0.3633 - val_accuracy: 0.9600 - val_loss: 0.3857
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9740 - loss: 0.3579 - val_accuracy: 0.9700 - val_loss: 0.3509
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9760 - loss: 0.3311 - val_accuracy: 0.9800 - val_loss: 0.3183
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9792 - loss: 0.3379 - val_accuracy: 0.9600 - val_loss: 0.3655
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9792 - loss: 0.3293 - val_accuracy: 0.9500 - val_loss: 0.3810
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9635 - loss: 0.3359 - val_accuracy: 0.9300 - val_loss: 0.3669
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9615 - loss: 0.3275 - val_accuracy: 0.9700 - val_loss: 0.3676
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.9667 - loss: 0.3445 - val_accuracy: 0.9500 - val_loss: 0.3279
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.9729 - loss: 0.3332 - val_accuracy: 0.9800 - val_loss: 0.3230
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9708 - loss: 0.3421 - val_accuracy: 0.9600 - val_loss: 0.3190
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.9771 - loss: 0.3381 - val_accuracy: 0.9900 - val_loss: 0.2887
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 121s 4s/step - accuracy: 0.9646 - loss: 0.3486 - val_accuracy: 0.9600 - val_loss: 0.3457
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9677 - loss: 0.4753 - val_accuracy: 0.9700 - val_loss: 0.5303
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9750 - loss: 0.5454 - val_accuracy: 0.9700 - val_loss: 0.5229
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9573 - loss: 0.5480 - val_accuracy: 0.9600 - val_loss: 0.5249
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9698 - loss: 0.5237 - val_accuracy: 0.9800 - val_loss: 0.4579
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.9708 - loss: 0.4634 - val_accuracy: 0.9700 - val_loss: 0.4345
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9729 - loss: 0.4839 - val_accuracy: 0.9700 - val_loss: 0.5047
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9677 - loss: 0.4854 - val_accuracy: 0.9900 - val_loss: 0.4280
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9771 - loss: 0.4280 - val_accuracy: 0.9800 - val_loss: 0.4175
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9844 - loss: 0.4054 - val_accuracy: 0.9600 - val_loss: 0.4079
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9833 - loss: 0.3694 - val_accuracy: 0.9600 - val_loss: 0.3913
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9885 - loss: 0.3483 - val_accuracy: 0.9500 - val_loss: 0.4034
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9906 - loss: 0.3464 - val_accuracy: 0.9300 - val_loss: 0.3889
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9865 - loss: 0.3097 - val_accuracy: 0.9500 - val_loss: 0.3634
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9833 - loss: 0.3074 - val_accuracy: 0.9800 - val_loss: 0.2943
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9865 - loss: 0.2762 - val_accuracy: 0.9900 - val_loss: 0.2717
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9885 - loss: 0.2699 - val_accuracy: 0.9800 - val_loss: 0.2875
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9823 - loss: 0.2808 - val_accuracy: 0.9700 - val_loss: 0.2748
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9760 - loss: 0.2898 - val_accuracy: 0.9900 - val_loss: 0.2729
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9844 - loss: 0.2890 - val_accuracy: 0.9800 - val_loss: 0.2967
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9812 - loss: 0.2906 - val_accuracy: 0.9500 - val_loss: 0.3933
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9865 - loss: 0.2874 - val_accuracy: 0.9900 - val_loss: 0.2866
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9719 - loss: 0.3206 - val_accuracy: 0.9700 - val_loss: 0.3197
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9729 - loss: 0.3010 - val_accuracy: 0.9700 - val_loss: 0.3013
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9760 - loss: 0.3037 - val_accuracy: 0.9800 - val_loss: 0.2938
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9698 - loss: 0.3378 - val_accuracy: 0.9500 - val_loss: 0.3627
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9729 - loss: 0.3328 - val_accuracy: 0.9600 - val_loss: 0.3167
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9781 - loss: 0.2990 - val_accuracy: 0.9700 - val_loss: 0.3182
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9792 - loss: 0.3029 - val_accuracy: 0.9600 - val_loss: 0.3555
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9812 - loss: 0.2935 - val_accuracy: 0.9700 - val_loss: 0.3057
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9802 - loss: 0.2886 - val_accuracy: 0.9400 - val_loss: 0.3688
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9771 - loss: 0.2878 - val_accuracy: 0.9500 - val_loss: 0.3578
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9729 - loss: 0.2903 - val_accuracy: 0.9600 - val_loss: 0.3477
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9875 - loss: 0.2614 - val_accuracy: 0.9400 - val_loss: 0.3470
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 121s 4s/step - accuracy: 0.9885 - loss: 0.2581 - val_accuracy: 0.9500 - val_loss: 0.3459
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9917 - loss: 0.2359 - val_accuracy: 0.9400 - val_loss: 0.3447
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9885 - loss: 0.2318 - val_accuracy: 0.9600 - val_loss: 0.3249
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9896 - loss: 0.2305 - val_accuracy: 0.9500 - val_loss: 0.3041
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9802 - loss: 0.2555 - val_accuracy: 0.9400 - val_loss: 0.3019
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9896 - loss: 0.2355 - val_accuracy: 0.9600 - val_loss: 0.3105
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.9833 - loss: 0.2532 - val_accuracy: 0.9700 - val_loss: 0.2675
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9812 - loss: 0.2544 - val_accuracy: 0.9600 - val_loss: 0.3185
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9823 - loss: 0.2509 - val_accuracy: 0.9800 - val_loss: 0.3221
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9875 - loss: 0.2552 - val_accuracy: 0.9200 - val_loss: 0.4384
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9719 - loss: 0.2949 - val_accuracy: 0.9700 - val_loss: 0.3475
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9760 - loss: 0.2876 - val_accuracy: 0.9400 - val_loss: 0.3770
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9708 - loss: 0.2942 - val_accuracy: 0.9600 - val_loss: 0.3799
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.9667 - loss: 0.3526 - val_accuracy: 0.9500 - val_loss: 0.4968
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9823 - loss: 0.4583 - val_accuracy: 0.9600 - val_loss: 0.5102
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9802 - loss: 0.4453 - val_accuracy: 0.9700 - val_loss: 0.5021
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9802 - loss: 0.3939 - val_accuracy: 0.9600 - val_loss: 0.4928
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9802 - loss: 0.3802 - val_accuracy: 0.9600 - val_loss: 0.4358
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9708 - loss: 0.3694 - val_accuracy: 0.9600 - val_loss: 0.4422
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.9677 - loss: 0.3500 - val_accuracy: 0.9700 - val_loss: 0.4113
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9729 - loss: 0.3481 - val_accuracy: 0.9500 - val_loss: 0.4633
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9708 - loss: 0.3700 - val_accuracy: 0.9400 - val_loss: 0.5216
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9729 - loss: 0.3698 - val_accuracy: 0.9400 - val_loss: 0.4912
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9771 - loss: 0.3654 - val_accuracy: 0.9500 - val_loss: 0.4412
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9854 - loss: 0.3252 - val_accuracy: 0.9600 - val_loss: 0.3973
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9896 - loss: 0.2884 - val_accuracy: 0.9400 - val_loss: 0.4023
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9781 - loss: 0.3241 - val_accuracy: 0.9600 - val_loss: 0.4780
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.9792 - loss: 0.5401 - val_accuracy: 0.9500 - val_loss: 0.6622
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9812 - loss: 0.5457 - val_accuracy: 0.9600 - val_loss: 0.6148
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9854 - loss: 0.5020 - val_accuracy: 0.9600 - val_loss: 0.5640
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9823 - loss: 0.4722 - val_accuracy: 0.9500 - val_loss: 0.5439
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9812 - loss: 0.4477 - val_accuracy: 0.9600 - val_loss: 0.4572
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9875 - loss: 0.4062 - val_accuracy: 0.9700 - val_loss: 0.4329
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9802 - loss: 0.3897 - val_accuracy: 0.9600 - val_loss: 0.4394
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9698 - loss: 0.3912 - val_accuracy: 0.9500 - val_loss: 0.3980
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9833 - loss: 0.3520 - val_accuracy: 0.9500 - val_loss: 0.4401
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9875 - loss: 0.3315 - val_accuracy: 0.9300 - val_loss: 0.4956
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9740 - loss: 0.3363 - val_accuracy: 0.9200 - val_loss: 0.4529
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9802 - loss: 0.3293 - val_accuracy: 0.9400 - val_loss: 0.4091
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9740 - loss: 0.3369 - val_accuracy: 0.9500 - val_loss: 0.4408
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9833 - loss: 0.3125 - val_accuracy: 0.9400 - val_loss: 0.4460
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9792 - loss: 0.3073 - val_accuracy: 0.9500 - val_loss: 0.4128
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9833 - loss: 0.3075 - val_accuracy: 0.9400 - val_loss: 0.4232
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9729 - loss: 0.4871 - val_accuracy: 0.9600 - val_loss: 0.6667
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9802 - loss: 0.5871 - val_accuracy: 0.9300 - val_loss: 0.8504
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9750 - loss: 0.6071 - val_accuracy: 0.9500 - val_loss: 0.7017
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9833 - loss: 0.5321 - val_accuracy: 0.9400 - val_loss: 0.7261

# %%
loaded_model = load_model('debug/9_2/model_41.keras')

# %%
test_pred = loaded_model.predict(predict_generator(test_files), steps=len(test_files))
# Out:
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 1764s 141ms/step

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[180:190], test_pred[180:190]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)
# Out:
# C:\Users\tyane\AppData\Local\Temp\ipykernel_27012\23744489.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   subplot.set_title('%.2f %s' % (score, os.path.basename(path)))

# %%
test_pred
# Out:
# array([[1.0000000e+00],
#        [1.7224677e-16],
#        [1.1022373e-18],
#        ...,
#        [1.0000000e+00],
#        [0.0000000e+00],
#        [5.6006332e-26]], shape=(12500, 1), dtype=float32)

# %%
import re

with open('data/result.csv', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))
# Out:
# C:\Users\tyane\AppData\Local\Temp\ipykernel_27012\2553654403.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))
